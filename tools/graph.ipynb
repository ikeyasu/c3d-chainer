# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
with open('../result/log') as f:
    logs = json.load(f)
    results = pd.DataFrame(logs)

# %%
results[['main/loss','validation/main/loss']].plot()

# %%
results[['main/accuracy','validation/main/accuracy']].plot()

# %%
import pandas as pd
df = pd.read_csv('../result.txt')
df.head(3)
# Out:
#     jumping jumping.1
# 0    tennis    tennis
# 1     swing    riding
# 2  shooting  shooting

# %%
from functools import reduce
incorrect = [1 if b[0] == b[1] else 0 for b in df.values]
incorrect = sum(incorrect)
incorrect / len(df.values)
# Out:
# 0.8585858585858586

# %%
df.head(2)
# Out:
#   jumping  jumping
# 0  tennis   tennis
# 1   swing   riding

# %%
df.values[0][1]
# Out:
# ' tennis'

# %%
'a' == 'a'
# Out:
# True

# %%
sum
# Out:
# <function sum>
